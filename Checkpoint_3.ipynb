# %% [markdown]
# # **DIMAS AJI MUKTI 2409116107**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/vgsales.csv')

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # **Analisis Business Understanding Video Game Sales** #

# %% [markdown]
# ## 1. Business Objective

# %% [markdown]
# Industri video game adalah salah satu sektor hiburan terbesar di dunia, dengan nilai pasar yang terus berkembang. Untuk memaksimalkan keuntungan, orang orang yang sangat peenting dalam hal ini seperti publisher, developer, dan investor perlu memahami faktor-faktor yang mempengaruhi kesuksesan game.
#
# Tujuan utama dari analisis ini adalah
#
# 1. Mengidentifikasi tren penjualan video game berdasarkan platform, genre, dan tahun rilis.
# 2. Menganalisis preferensi pasar di berbagai wilayah (Amerika Utara, Eropa, Jepang, dan lainnya).
# 3. Mengetahui publisher paling sukses berdasarkan total penjualan global.
# 4. Memberikan wawasan yang dapat membantu strategi pemasaran dan pengembangan produk di industri game.

# %% [markdown]
# #2. Assess Situation

# %% [markdown]
# Dataset ini berisi informasi penjualan video game dengan total 16.598 entri dan 11 atribut utama, termasuk nama game, platform, tahun rilis, genre, publisher, serta data penjualan di berbagai wilayah.
#
# 1. Missing Values: Terdapat nilai yang hilang pada kolom Year dan Publisher, yang harus ditangani agar analisis lebih akurat.
# 2. Representasi Data: Dataset ini mungkin tidak mencakup semua game yang pernah dirilis, tetapi hanya game dengan data penjualan yang tersedia.
# 3. Faktor Eksternal: Data ini tidak mencakup faktor seperti strategi pemasaran, ulasan pengguna, atau tren sosial yang juga berpengaruh terhadap penjualan game.
#
# Ketiga ini merupakan kondisi dan tantangan.

# %% [markdown]
# # 3. Data Mining Goals

# %% [markdown]
# Agar analisis dapat memberikan wawasan yang bernilai, beberapa tujuan spesifik dalam eksplorasi data adalah
#
# **Analisis Tren Penjualan**:
# Melihat pola penjualan dari waktu ke waktu untuk memahami perkembangan industri game.
# Mengidentifikasi platform dengan performa terbaik dalam jangka panjang.
#
# **Segmentasi Pasar Berdasarkan Wilayah:**
# Mengetahui apakah ada perbedaan selera genre antar wilayah (misalnya, RPG lebih populer di Jepang dibandingkan di Amerika).
# Menganalisis game yang berhasil di satu wilayah tetapi kurang sukses di wilayah lain.
#
# **Evaluasi Kinerja Publisher:**
# Mengidentifikasi publisher dengan total penjualan tertinggi.
# Mengetahui apakah ada publisher yang lebih unggul dalam genre atau platform tertentu.
#
# **Prediksi Game Sukses:**
# Menggunakan pola dari data historis untuk memperkirakan game dengan potensi penjualan tinggi.
# Menentukan faktor utama yang berkontribusi terhadap kesuksesan sebuah game.

# %% [markdown]
# # 4. Project Plan

# %% [markdown]
# 1. Data Preparation
# Menghapus atau mengisi nilai yang hilang.
# Menyesuaikan format data agar mudah dianalisis.
# Mengonversi variabel numerik atau kategorikal jika diperlukan.
# 2. Exploratory Data Analysis (EDA)
# Membuat visualisasi tren penjualan berdasarkan tahun, platform, dan wilayah.
# Melihat distribusi genre game yang paling populer.
# Menemukan insight dari peringkat penjualan game.
# 3. Modeling & Prediction (Opsional)
# Jika diperlukan, dapat dibuat model prediksi untuk memperkirakan potensi keberhasilan sebuah game.
# Menggunakan algoritma statistik atau machine learning untuk menemukan pola tersembunyi.
# 4. Interpretation & Business Recommendations
# Menyusun laporan insight yang bisa digunakan untuk pengambilan keputusan.
# Memberikan rekomendasi berbasis data untuk publisher dan developer.

# %% [markdown]
# # **Data preparation**

# %% [markdown]
# # Mengecek Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Rank            0.000000
# Name            0.000000
# Platform        0.000000
# Year            1.632727
# Genre           0.000000
# Publisher       0.349440
# NA_Sales        0.000000
# EU_Sales        0.000000
# JP_Sales        0.000000
# Other_Sales     0.000000
# Global_Sales    0.000000
# dtype: float64

# %% [markdown]
# # Mengecek Nilai Kosong yang ada di 'Year dan Publisher'

# %%
df[df['Year'].isnull()]
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df[df['Publisher'].isnull()]
# Out:
#         Rank                                               Name Platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %% [markdown]
# # Mengatasi Missing Values, data yang hilang <=70%

# %%
df['Year'].dropna().describe()
# Out:
# count    16327.000000
# mean      2006.406443
# std          5.828981
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %% [markdown]
# # Dikarenakan Missing Values dari kolom year dan publisher masih dibawah 70% maka hanya akan dilakukan IMPUTASI untuk nilai yang kosong

# %%
df['Publisher'].dropna().describe()
# Out:
# count               16540
# unique                578
# top       Electronic Arts
# freq                 1351
# Name: Publisher, dtype: object

# %%
df = df.dropna(subset=["Year"])
df["Year"] = df["Year"].astype(int)
# Out:
# <ipython-input-8-d580cf8bbfe4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] = df["Year"].astype(int)

# %%
df['Year'] = df['Year'].fillna(df['Year'].dropna().mean())
# Out:
# <ipython-input-9-95f47f0d4625>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].fillna(df['Year'].dropna().mean())

# %%
df['Publisher'] = df['Publisher'].fillna(df['Publisher'].dropna().count())
# Out:
# <ipython-input-10-da25fe9b7d58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Publisher'] = df['Publisher'].fillna(df['Publisher'].dropna().count())

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#               Null Ratio %
# Rank                   0.0
# Name                   0.0
# Platform               0.0
# Year                   0.0
# Genre                  0.0
# Publisher              0.0
# NA_Sales               0.0
# EU_Sales               0.0
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales           0.0

# %% [markdown]
# # Selanjutnya akan dicek apakah ada data yang terduplikat

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# # Karena tidak ada data yang terduplikat maka tidak perlu mengatasi apapun

# %% [markdown]
# # Selanjutnya mengecek **outliers** jika ada data yang nilainya jauh lebih rendah ata lebih tinggi

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# Rank                     0.000000
# Year                     1.868071
# NA_Sales                10.167208
# EU_Sales                12.580388
# JP_Sales                14.742451
# Other_Sales             10.075335
# Global_Sales            11.190053

# %% [markdown]
# # Dikarenakan Presentase nya tidak terlalu tinggi namun variabel penting maka akan dilakukan **imputasi winsoirizing** agar tidak mengubah struktur datanya

# %%
columns_to_impute = ["Year", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# <ipython-input-15-c5369443fa46>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2006.  1992.5 2008.  ... 2008.  2010.  2003. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# # Pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# Rank                          0.0
# Year                          0.0
# NA_Sales                      0.0
# EU_Sales                      0.0
# JP_Sales                      0.0
# Other_Sales                   0.0
# Global_Sales                  0.0

# %% [markdown]
# # Selanjutnya kita akan pengecekan nilai yang tidak konsisten dari data "INCONSISTENT VALUE"

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Karena tidak ada nilai yang tidak konsisten di data ini, maka tidak perlu melakukan penanganan

# %% [markdown]
# # Menurut saya karena data ini sudah sangat relevan dan tidak perlu ada penambahan kolom ataupun penghapusan, Maka saya tidak menggunakan Construct Data.

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # **VISUALISASI DATA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Visualisasi data relevan dengan Video Game Sales

# %% [markdown]
# # 1. Mengidentifikasi tren penjualan video game berdasarkan platform, genre, dan tahun rilis.

# %%
yearly_sales = df.groupby("Year")[["Global_Sales"]].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=yearly_sales, x="Year", y="Global_Sales", marker="o", color="b")
plt.title("Tren Penjualan Video Game Global Berdasarkan Tahun Rilis", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Total Penjualan (Juta Unit)", fontsize=12)
plt.grid(True)
plt.show()

# %%
platform_sales = df.groupby(["Year", "Platform"])[["Global_Sales"]].sum().reset_index()

plt.figure(figsize=(14, 7))
sns.lineplot(data=platform_sales, x="Year", y="Global_Sales", hue="Platform", linewidth=1.5)
plt.title("Tren Penjualan Video Game Berdasarkan Platform", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Total Penjualan (Juta Unit)", fontsize=12)
plt.legend(title="Platform")
plt.grid(True)
plt.show()

# %%
genre_sales = df.groupby(["Year", "Genre"])[["Global_Sales"]].sum().reset_index()

plt.figure(figsize=(14, 7))
sns.lineplot(data=genre_sales, x="Year", y="Global_Sales", hue="Genre", linewidth=1.5)
plt.title("Tren Penjualan Video Game Berdasarkan Genre", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Total Penjualan (Juta Unit)", fontsize=12)
plt.legend(title="Genre")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Menganalisis preferensi pasar di berbagai wilayah (Amerika Utara, Eropa, Jepang, dan lainnya).

# %%
region_sales = df.groupby("Year")[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]].sum().reset_index()

plt.figure(figsize=(14, 7))
sns.lineplot(data=region_sales, x="Year", y="NA_Sales", label="Amerika Utara", color="blue")
sns.lineplot(data=region_sales, x="Year", y="EU_Sales", label="Eropa", color="green")
sns.lineplot(data=region_sales, x="Year", y="JP_Sales", label="Jepang", color="red")
sns.lineplot(data=region_sales, x="Year", y="Other_Sales", label="Lainnya", color="purple")

plt.title("Tren Penjualan Video Game di Berbagai Wilayah", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Total Penjualan (Juta Unit)", fontsize=12)
plt.legend(title="Wilayah")
plt.grid(True)
plt.show()

# %% [markdown]
# # 3. Mengetahui publisher paling sukses berdasarkan total penjualan global.

# %%
publisher_sales = df.groupby("Publisher")[["Global_Sales"]].sum().reset_index()

top_publishers = publisher_sales.sort_values(by="Global_Sales", ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_publishers, y="Publisher", x="Global_Sales", palette="Blues_r")
plt.title("Top 10 Publisher Paling Sukses Berdasarkan Total Penjualan Global", fontsize=14)
plt.xlabel("Total Penjualan (Juta Unit)", fontsize=12)
plt.ylabel("Publisher", fontsize=12)
plt.grid(axis="x")
plt.show()
# Out:
# <ipython-input-24-8873d7720314>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_publishers, y="Publisher", x="Global_Sales", palette="Blues_r")

# %% [markdown]
# # 4. Wawasan untuk Strategi Pemasaran & Pengembangan Produk

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.barplot(y=platform_sales.index, x=platform_sales.values, hue=platform_sales.index, palette='coolwarm', legend=False, ax=axes[0])
axes[0].set_title("Total Penjualan Berdasarkan Platform (Eksklusivitas)")
axes[0].set_xlabel("Total Penjualan (Juta Unit)")
axes[0].set_ylabel("Platform")

sns.barplot(data=genre_sales, y='Genre', x='Global_Sales', hue='Genre', palette='viridis', legend=False, ax=axes[1])
axes[1].set_title("Total Penjualan Berdasarkan Genre (Live-Service)")
axes[1].set_xlabel("Total Penjualan (Juta Unit)")
axes[1].set_ylabel("Genre")

sns.barplot(data=model_sales, x='Model', y='Global_Sales', hue='Model', palette='pastel', legend=False, ax=axes[2])
axes[2].set_title("Total Penjualan Berdasarkan Model Game (F2P vs Premium)")
axes[2].set_xlabel("Model Game")
axes[2].set_ylabel("Total Penjualan (Juta Unit)")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-59bd0d65ee35> in <cell line: 0>()
#       1 fig, axes = plt.subplots(1, 3, figsize=(18, 5))
#       2
# ----> 3 sns.barplot(y=platform_sales.index, x=platform_sales.values, hue=platform_sales.index, palette='coolwarm', legend=False, ax=axes[0])
#       4 axes[0].set_title("Total Penjualan Berdasarkan Platform (Eksklusivitas)")
#       5 axes[0].set_xlabel("Total Penjualan (Juta Unit)")
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2339         estimator = "size"
#    2340
# -> 2341     p = _CategoricalAggPlotter(
# ...

# %% [markdown]
# # **Insight dan Tindakan yang dapat diambil dari data tersebut**

# %% [markdown]
# # 1. Identifikasi Tren Penjualan Video Game Berdasarkan Platform, Genre, dan Tahun Rilis.
# # Insight =
# Tren berdasarkan tahun: Penjualan global mengalami puncak di beberapa tahun tertentu, kemudian menurun setelahnya.
# Tren berdasarkan platform: Platform populer mengalami siklus kejayaan masing-masing (misalnya, NES di era 90-an, PlayStation di era 2000-an, dan Switch di era sekarang).
# Tren berdasarkan genre: Genre Action, Shooter, dan Sports memiliki tingkat penjualan tertinggi, sedangkan Racing dan RPG memiliki basis penggemar yang stabil.
#
# # Tindakan =
# Fokus pada platform yang sedang tren, seperti konsol generasi terbaru atau mobile gaming yang semakin berkembang.
# Mengembangkan game dengan genre yang populer, seperti Action dan Shooter, serta mempertahankan basis penggemar genre lain melalui inovasi dan fitur tambahan.
#  Mengantisipasi tren masa depan, seperti cloud gaming dan augmented reality (AR), agar tetap kompetitif dalam industri.

# %% [markdown]
# # 2. Analisis Preferensi Pasar di Berbagai Wilayah.
#
# #Insight =
# Amerika Utara dan Eropa menjadi pasar terbesar untuk video game, dengan dominasi genre Action dan Shooter.
# Jepang memiliki preferensi unik terhadap genre RPG dan game berbasis handheld.
# Wilayah lain (Asia selain Jepang dan Amerika Selatan) mulai berkembang, meskipun masih tertinggal dibanding pasar utama.
# #Tindakan =
# Menyesuaikan strategi pemasaran per wilayah, misalnya promosi game FPS di Amerika Utara dan RPG di Jepang. Memperluas ke pasar berkembang dengan meningkatkan distribusi game di Asia dan Amerika Selatan.Menyesuaikan gaya gameplay dan fitur game agar lebih sesuai dengan preferensi pemain di berbagai wilayah.

# %% [markdown]
# # 3. Publisher Paling Sukses Berdasarkan Total Penjualan Global
# #Insight =
# Nintendo, EA, dan Activision adalah publisher paling dominan dalam industri.
# Publisher besar mampu bertahan dengan franchise kuat, seperti FIFA, Call of Duty, dan Super Mario.
# Publisher kecil menghadapi tantangan besar dalam bersaing dengan raksasa industri.
# #Tindakan =
# Publisher besar harus terus mempertahankan loyalitas pemain dengan franchise mereka dan konten tambahan (DLC, update, dan event khusus). Publisher kecil dapat sukses dengan strategi niche, seperti game indie dengan konsep unik atau game berbasis komunitas. Kolaborasi dengan influencer dan komunitas gaming dapat meningkatkan daya tarik game baru, terutama bagi studio kecil.

# %% [markdown]
# # 4. Wawasan untuk Strategi Pemasaran & Pengembangan Produk
# #Insight =
# Game dengan live-service model (DLC, ekspansi, dan microtransactions) memiliki peluang sukses lebih tinggi.
# Eksklusivitas platform masih menjadi strategi yang efektif untuk meningkatkan daya tarik konsol tertentu.
# Free-to-play dengan monetisasi dalam game semakin populer dan memberikan pendapatan besar bagi developer.
# #Tindakan =
# Mengadopsi model live-service, seperti update konten berkala dan mode multiplayer yang terus berkembang. Memanfaatkan game eksklusif sebagai strategi utama untuk meningkatkan daya tarik platform tertentu. Eksplorasi model free-to-play dengan monetisasi adil, seperti sistem kosmetik atau battle pass, agar dapat menjangkau lebih banyak pemain.

# %%
df.to_csv('video_game_sales_cleaned.csv', index=False)
